# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)

lado_kohonen = [3,5,7,10,20,30,40,50]
n_clases = [9,24,39,59,77,86,88,92]
error_cuantificable = [0.3,0.19,0.14,0.1,0.08,0.08,0.08,0.07]
error_topologico = [0.04,0.06,0.03,0.06,0.07,0.07,0.12,0.11]

plt.xlabel('Lado kohonen')
plt.ylabel('Clases')
# Influencia del lado KHONONEN en número de clases
linea_clases = plt.plot(lado_kohonen,n_clases,'r')
plt.twinx()
# Influencia del lado KHONONEN en errores
plt.ylabel('Errores')
# Error cuantificable
linea_cuantificable = plt.plot(lado_kohonen,error_cuantificable,'g') 
plt.twiny()
# Error topológico
linea_topologico = plt.plot(lado_kohonen,error_topologico,'b') 

# EL MEJOR LADO DE KOHONEN ES 30

# %%
aprendizaje = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7]
n_clases_a = [84,85,84,83,88,88,83,88,88,88,87,84,85.7]
error_cuantificable_a = [0.08,0.08,0.08,0.07,0.07,0.07,0.08,0.06,0.05,0.06,0.07,0.06,0.06]
error_topologico_a = [0.06,0.05,0.1,0.07,0.07,0.08,0.07,0.09,0.12,0.08,0.09,0.08,0.11]

figure(figsize=(8, 6), dpi=80)
plt.xlabel('Coeficiente aprendizaje')
plt.ylabel('Clases')
# Influencia del Coeficiente en número de clases
linea_clases = plt.plot(aprendizaje,n_clases_a,'r')
plt.twinx()
# Influencia del Coeficiente en errores
plt.ylabel('Errores')
# Error cuantificable
linea_cuantificable = plt.plot(aprendizaje,error_cuantificable_a,'g') 
plt.twiny()
# Error topológico
linea_topologico = plt.plot(aprendizaje,error_topologico_a,'b') 

# EL MEJOR APRENDIZAJE ES 0.3

# %%
periodo = [250,500,750,1000,1250,1500,1750,2000,2250,2500,2750,3000,
          3250,3500,3750,4000,4250,4500,4750,5000,6000,7000,8000,9000,
          10000,15000,20000,25000,30000,40000]
n_clases_p = [86,86,86,90,88,88,90,87,88,88,88,87,89,89,88,88,86,91,89,90,
              88,89,91,90,87,86,90,89,90,89]
error_cuantificable_p = [0.09,0.08,0.08,0.07,0.07,0.07,0.07,0.07,0.06,0.06,
                        0.06,0.06,0.06,0.06,0.06,0.06,0.06,0.05,0.05,0.06,
                        0.06,0.06,0.06,0.06,0.05,0.06,0.05,0.05,0.05,0.05]
error_topologico_p = [0.17,0.1,0.12,0.09,0.07,0.08,0.08,0.07,0.06,0.08,0.07,
                      0.07,0.08,0.09,0.08,0.07,0.07,0.06,0.05,0.06,0.07,0.07,
                      0.08,0.08,0.1,0.1,0.1,0.12,0.15,0.15]

figure(figsize=(30, 5), dpi=80)
plt.xlabel('Periodo')
plt.ylabel('Clases')
# Influencia periodo en número de clases
linea_clases = plt.plot(periodo,n_clases_p,'r')
plt.twinx()
# Influencia periodo en errores
plt.ylabel('Errores')
# Error cuantificable
linea_cuantificable = plt.plot(periodo,error_cuantificable_p,'g') 
plt.twiny()
# Error topológico
linea_topologico = plt.plot(periodo,error_topologico_p,'b') 

# EL MEJOR PERIODO ES
